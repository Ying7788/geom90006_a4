# %% [markdown]
# ## 7. Social Vulnerability Analysis
#
# This section uses ABS Census data to measure social vulnerability at the SA2 level. The indicators include median household income, elderly population percentage, children population percentage and population density.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
import os
print(os.listdir("data/raw"))
os.makedirs("data/processed", exist_ok=True)
os.makedirs("output/figures", exist_ok=True)
os.makedirs("output/tables", exist_ok=True)
# Out:
# ['.DS_Store', 'open_space', 'urban_heat_cegetation_2018', 'abs_boundary', 'census_datapack']

# %%
boundary_files = []

for root, dirs, files in os.walk("data/raw/abs_boundary"):
    for file in files:
        if file.endswith(".shp") or file.endswith(".gpkg"):
            boundary_files.append(os.path.join(root, file))

boundary_files
# Out:
# ['data/raw/abs_boundary/ASGS_2021_Main_Structure_GDA2020.gpkg']

# %%
# load boundary file
sa2 = gpd.read_file(boundary_files[0])

sa2.head()
# Out:
#   MB_CODE_2021 MB_CATEGORY_2021 CHANGE_FLAG_2021 CHANGE_LABEL_2021  \
# 0  10000010000      Residential                0         No change
# 1  10000021000       Commercial                0         No change
# 2  10000022000       Commercial                0         No change
# 3  10000023000       Commercial                0         No change
# 4  10000024000      Residential                0         No change
#
#   SA1_CODE_2021 SA2_CODE_2021  SA2_NAME_2021 SA3_CODE_2021 SA3_NAME_2021  \
# 0   10901117207     109011172  Albury - East         10901        Albury
# 1   10901117612     109011176      Lavington         10901        Albury
# 2   10901117621     109011176      Lavington         10901        Albury
# 3   10901117621     109011176      Lavington         10901        Albury
# 4   10901117613     109011176      Lavington         10901        Albury
#
#   SA4_CODE_2021 SA4_NAME_2021 GCCSA_CODE_2021 GCCSA_NAME_2021 STATE_CODE_2021  \
# 0           109        Murray           1RNSW     Rest of NSW               1
# 1           109        Murray           1RNSW     Rest of NSW               1
# 2           109        Murray           1RNSW     Rest of NSW               1
# 3           109        Murray           1RNSW     Rest of NSW               1
# 4           109        Murray           1RNSW     Rest of NSW               1
#
#    STATE_NAME_2021 AUS_CODE_2021 AUS_NAME_2021  AREA_ALBERS_SQKM  \
# 0  New South Wales           AUS     Australia            0.0209
# 1  New South Wales           AUS     Australia            0.0829
# 2  New South Wales           AUS     Australia            0.0388
# 3  New South Wales           AUS     Australia            0.0254
# 4  New South Wales           AUS     Australia            0.0376
#
#                                   ASGS_LOCI_URI_2021  \
# 0  http://linked.data.gov.au/dataset/asgsed3/MB/1...
# 1  http://linked.data.gov.au/dataset/asgsed3/MB/1...
# 2  http://linked.data.gov.au/dataset/asgsed3/MB/1...
# 3  http://linked.data.gov.au/dataset/asgsed3/MB/1...
# 4  http://linked.data.gov.au/dataset/asgsed3/MB/1...
#
#                                             geometry
# 0  POLYGON ((146.92785 -36.08365, 146.92855 -36.0...
# 1  POLYGON ((146.93543 -36.04752, 146.93448 -36.0...
# 2  POLYGON ((146.93040 -36.04996, 146.93087 -36.0...
# 3  POLYGON ((146.93254 -36.05238, 146.93288 -36.0...
# 4  POLYGON ((146.93044 -36.04733, 146.93118 -36.0...

# %%
# keep Greater Melbourne only
melb_mb = sa2[sa2["GCCSA_NAME_2021"] == "Greater Melbourne"].copy()
melb_mb.head()
# Out:
#        MB_CODE_2021 MB_CATEGORY_2021 CHANGE_FLAG_2021 CHANGE_LABEL_2021  \
# 114329  20015400000      Residential                0         No change
# 114330  20015410000      Residential                0         No change
# 114331  20015420000      Residential                0         No change
# 114332  20015430000      Residential                0         No change
# 114333  20015440000      Residential                0         No change
#
#        SA1_CODE_2021 SA2_CODE_2021         SA2_NAME_2021 SA3_CODE_2021  \
# 114329   20901119918     209011199       Heidelberg West         20901
# 114330   20901120346     209011203  Viewbank - Yallambie         20901
# 114331   20901120316     209011203  Viewbank - Yallambie         20901
# 114332   20901120318     209011203  Viewbank - Yallambie         20901
# 114333   20901120012     209011200               Ivanhoe         20901
#
#        SA3_NAME_2021 SA4_CODE_2021           SA4_NAME_2021 GCCSA_CODE_2021  \
# 114329       Banyule           209  Melbourne - North East           2GMEL
# 114330       Banyule           209  Melbourne - North East           2GMEL
# 114331       Banyule           209  Melbourne - North East           2GMEL
# 114332       Banyule           209  Melbourne - North East           2GMEL
# 114333       Banyule           209  Melbourne - North East           2GMEL
#
#           GCCSA_NAME_2021 STATE_CODE_2021 STATE_NAME_2021 AUS_CODE_2021  \
# 114329  Greater Melbourne               2        Victoria           AUS
# 114330  Greater Melbourne               2        Victoria           AUS
# 114331  Greater Melbourne               2        Victoria           AUS
# 114332  Greater Melbourne               2        Victoria           AUS
# 114333  Greater Melbourne               2        Victoria           AUS
#
#        AUS_NAME_2021  AREA_ALBERS_SQKM  \
# 114329     Australia            0.0125
# 114330     Australia            0.0271
# 114331     Australia            0.0443
# 114332     Australia            0.0456
# 114333     Australia            0.0245
#
#                                        ASGS_LOCI_URI_2021  \
# 114329  http://linked.data.gov.au/dataset/asgsed3/MB/2...
# 114330  http://linked.data.gov.au/dataset/asgsed3/MB/2...
# 114331  http://linked.data.gov.au/dataset/asgsed3/MB/2...
# 114332  http://linked.data.gov.au/dataset/asgsed3/MB/2...
# 114333  http://linked.data.gov.au/dataset/asgsed3/MB/2...
#
#                                                  geometry
# 114329  POLYGON ((145.05212 -37.75717, 145.05219 -37.7...
# 114330  POLYGON ((145.09580 -37.73579, 145.09559 -37.7...
# 114331  POLYGON ((145.09626 -37.73345, 145.09745 -37.7...
# 114332  POLYGON ((145.10105 -37.73164, 145.10155 -37.7...
# 114333  POLYGON ((145.03223 -37.75918, 145.03206 -37.7...

# %%
# dissolve small areas into SA2 boundary
sa2_melb = melb_mb.dissolve(
    by=["SA2_CODE_2021", "SA2_NAME_2021"],
    as_index=False)

sa2_melb.head()
# Out:
#   SA2_CODE_2021      SA2_NAME_2021  \
# 0     206011106     Brunswick East
# 1     206011107     Brunswick West
# 2     206011109  Pascoe Vale South
# 3     206011495  Brunswick - North
# 4     206011496  Brunswick - South
#
#                                             geometry MB_CODE_2021  \
# 0  POLYGON ((144.97070 -37.77828, 144.97075 -37.7...  20460350000
# 1  POLYGON ((144.93734 -37.77781, 144.93708 -37.7...  20460950000
# 2  POLYGON ((144.93338 -37.75181, 144.93207 -37.7...  20466240000
# 3  POLYGON ((144.95555 -37.76344, 144.95460 -37.7...  20460461000
# 4  POLYGON ((144.95167 -37.77700, 144.95030 -37.7...  20460490000
#
#   MB_CATEGORY_2021 CHANGE_FLAG_2021 CHANGE_LABEL_2021 SA1_CODE_2021  \
# 0      Residential                0         No change   20601110609
# 1      Residential                0         No change   20601110706
# 2      Residential                0         No change   20601110905
# 3      Residential                0         No change   20601149503
# 4      Residential                0         No change   20601149601
#
#   SA3_CODE_2021       SA3_NAME_2021 SA4_CODE_2021      SA4_NAME_2021  \
# 0         20601  Brunswick - Coburg           206  Melbourne - Inner
# 1         20601  Brunswick - Coburg           206  Melbourne - Inner
# 2         20601  Brunswick - Coburg           206  Melbourne - Inner
# 3         20601  Brunswick - Coburg           206  Melbourne - Inner
# 4         20601  Brunswick - Coburg           206  Melbourne - Inner
#
#   GCCSA_CODE_2021    GCCSA_NAME_2021 STATE_CODE_2021 STATE_NAME_2021  \
# 0           2GMEL  Greater Melbourne               2        Victoria
# 1           2GMEL  Greater Melbourne               2        Victoria
# 2           2GMEL  Greater Melbourne               2        Victoria
# 3           2GMEL  Greater Melbourne               2        Victoria
# 4           2GMEL  Greater Melbourne               2        Victoria
#
#   AUS_CODE_2021 AUS_NAME_2021  AREA_ALBERS_SQKM  \
# 0           AUS     Australia            0.0169
# 1           AUS     Australia            0.0259
# 2           AUS     Australia            0.0263
# 3           AUS     Australia            0.0086
# 4           AUS     Australia            0.0167
#
#                                   ASGS_LOCI_URI_2021
# 0  http://linked.data.gov.au/dataset/asgsed3/MB/2...
# 1  http://linked.data.gov.au/dataset/asgsed3/MB/2...
# 2  http://linked.data.gov.au/dataset/asgsed3/MB/2...
# 3  http://linked.data.gov.au/dataset/asgsed3/MB/2...
# 4  http://linked.data.gov.au/dataset/asgsed3/MB/2...

# %%
sa2_melb = sa2_melb.rename(columns={
    "SA2_CODE_2021": "SA2_CODE",
    "SA2_NAME_2021": "SA2_NAME"})
sa2_melb = sa2_melb[["SA2_CODE", "SA2_NAME", "geometry"]]

sa2_melb.head()
# Out:
#     SA2_CODE           SA2_NAME  \
# 0  206011106     Brunswick East
# 1  206011107     Brunswick West
# 2  206011109  Pascoe Vale South
# 3  206011495  Brunswick - North
# 4  206011496  Brunswick - South
#
#                                             geometry
# 0  POLYGON ((144.97070 -37.77828, 144.97075 -37.7...
# 1  POLYGON ((144.93734 -37.77781, 144.93708 -37.7...
# 2  POLYGON ((144.93338 -37.75181, 144.93207 -37.7...
# 3  POLYGON ((144.95555 -37.76344, 144.95460 -37.7...
# 4  POLYGON ((144.95167 -37.77700, 144.95030 -37.7...

# %%
# project to a projected CRS for area calculation
sa2_melb = sa2_melb.to_crs(epsg=7855)

# calculate SA2 area in km2
sa2_melb["area_km2"] = sa2_melb.geometry.area / 1000000

sa2_melb[["SA2_CODE", "SA2_NAME", "area_km2"]].head()
# Out:
#     SA2_CODE           SA2_NAME  area_km2
# 0  206011106     Brunswick East  2.167998
# 1  206011107     Brunswick West  3.178667
# 2  206011109  Pascoe Vale South  2.988928
# 3  206011495  Brunswick - North  2.408738
# 4  206011496  Brunswick - South  2.733708

# %%
# quick map check
fig, ax = plt.subplots(figsize=(8, 8))

sa2_melb.plot(
    ax=ax,
    edgecolor="black",
    linewidth=0.2
)

ax.set_title("Greater Melbourne SA2 boundary")
ax.axis("off")

plt.show()

# %%
# save cleaned SA2 boundary
sa2_melb.to_file(
    "data/processed/sa2_melbourne_clean.gpkg",
    driver="GPKG"
)

# %%
# read G01 and G02 census tables
g01 = pd.read_csv("data/raw/census_datapack/SA2/VIC/2021Census_G01_VIC_SA2.csv")
g02 = pd.read_csv("data/raw/census_datapack/SA2/VIC/2021Census_G02_VIC_SA2.csv")

g01.head()
# Out:
#    SA2_CODE_2021  Tot_P_M  Tot_P_F  Tot_P_P  Age_0_4_yr_M  Age_0_4_yr_F  \
# 0      201011001     8188     8648    16835           623           585
# 1      201011002     5711     6420    12131           267           224
# 2      201011005     3594     3664     7261           190           172
# 3      201011006     5111     5553    10661           382           426
# 4      201011007     2172     2055     4230           125            99
#
#    Age_0_4_yr_P  Age_5_14_yr_M  Age_5_14_yr_F  Age_5_14_yr_P  ...  \
# 0          1213           1453           1364           2815  ...
# 1           490            658            630           1290  ...
# 2           357            561            587           1148  ...
# 3           804            784            683           1464  ...
# 4           223            338            326            668  ...
#
#    High_yr_schl_comp_Yr_8_belw_P  High_yr_schl_comp_D_n_g_sch_M  \
# 0                            430                             23
# 1                            355                             10
# 2                            169                             10
# 3                            408                             22
# 4                            126                              4
#
#    High_yr_schl_comp_D_n_g_sch_F  High_yr_schl_comp_D_n_g_sch_P  \
# 0                             22                             45
# 1                             13                             22
# 2                              8                             14
# 3                             13                             39
# 4                              3                              8
#
#    Count_psns_occ_priv_dwgs_M  Count_psns_occ_priv_dwgs_F  \
# 0                        7786                        8263
# 1                        5152                        5811
# 2                        3308                        3417
# 3                        4837                        5211
# 4                        2099                        2013
#
#    Count_psns_occ_priv_dwgs_P  Count_Persons_other_dwgs_M  \
# 0                       16055                         268
# 1                       10969                         755
# 2                        6722                         217
# 3                       10052                         227
# 4                        4107                          37
#
#    Count_Persons_other_dwgs_F  Count_Persons_other_dwgs_P
# 0                         313                         585
# 1                         766                        1521
# 2                         215                         435
# 3                         270                         501
# 4                          37                          71
#
# [5 rows x 109 columns]

# %%
g01_clean = g01.copy()

g01_clean["SA2_CODE"] = g01_clean["SA2_CODE_2021"].astype(str)

# calculate children population
g01_clean["children_pop"] = (
    g01_clean["Age_0_4_yr_P"] +
    g01_clean["Age_5_14_yr_P"])

# calculate elderly population
g01_clean["elderly_pop"] = (
    g01_clean["Age_65_74_yr_P"] +
    g01_clean["Age_75_84_yr_P"] +
    g01_clean["Age_85ov_P"])

# total population
g01_clean["total_population"] = g01_clean["Tot_P_P"]

# calculate percentage
g01_clean["children_pct"] = (
    g01_clean["children_pop"] / g01_clean["total_population"] * 100)

g01_clean["elderly_pct"] = (
    g01_clean["elderly_pop"] / g01_clean["total_population"] * 100)

g01_clean = g01_clean[["SA2_CODE",
        "children_pop",
        "elderly_pop",
        "total_population",
        "children_pct",
        "elderly_pct"]]

g01_clean.head()
# Out:
#     SA2_CODE  children_pop  elderly_pop  total_population  children_pct  \
# 0  201011001          4028         2178             16835     23.926344
# 1  201011002          1780         2826             12131     14.673151
# 2  201011005          1505         1334              7261     20.727173
# 3  201011006          2268         1578             10661     21.273802
# 4  201011007           891          608              4230     21.063830
#
#    elderly_pct
# 0    12.937333
# 1    23.295689
# 2    18.372125
# 3    14.801613
# 4    14.373522

# %%
g02_clean = g02.copy()
g02_clean["SA2_CODE"] = g02_clean["SA2_CODE_2021"].astype(str)

# use median household income
g02_clean["median_income"] = g02_clean["Median_tot_hhd_inc_weekly"]

# keep useful columns
g02_clean = g02_clean[["SA2_CODE", "median_income"]]

g02_clean.head()
# Out:
#     SA2_CODE  median_income
# 0  201011001           1952
# 1  201011002           1573
# 2  201011005           1927
# 3  201011006           1627
# 4  201011007           2065

# %%
# merge age/population table with income table
census_clean = g01_clean.merge(
    g02_clean,
    on="SA2_CODE",
    how="left")

census_clean.head()
# Out:
#     SA2_CODE  children_pop  elderly_pop  total_population  children_pct  \
# 0  201011001          4028         2178             16835     23.926344
# 1  201011002          1780         2826             12131     14.673151
# 2  201011005          1505         1334              7261     20.727173
# 3  201011006          2268         1578             10661     21.273802
# 4  201011007           891          608              4230     21.063830
#
#    elderly_pct  median_income
# 0    12.937333           1952
# 1    23.295689           1573
# 2    18.372125           1927
# 3    14.801613           1627
# 4    14.373522           2065

# %%
# remove rows with missing values
census_clean = census_clean.dropna()

# %%
# check SA2 boundary
sa2_melb.head()
# Out:
#     SA2_CODE           SA2_NAME  \
# 0  206011106     Brunswick East
# 1  206011107     Brunswick West
# 2  206011109  Pascoe Vale South
# 3  206011495  Brunswick - North
# 4  206011496  Brunswick - South
#
#                                             geometry  area_km2
# 0  POLYGON ((321288.586 5816845.702, 321292.072 5...  2.167998
# 1  POLYGON ((318349.303 5816833.955, 318326.042 5...  3.178667
# 2  POLYGON ((317936.341 5819710.405, 317821.095 5...  2.988928
# 3  POLYGON ((319918.451 5818463.626, 319833.841 5...  2.408738
# 4  POLYGON ((319609.469 5816951.224, 319488.337 5...  2.733708

# %%
# merge census data with SA2 boundary
sa2_census = sa2_melb.merge(
    census_clean,
    on="SA2_CODE",
    how="left")

# calculate population density
sa2_census["population_density"] = (
    sa2_census["total_population"] / sa2_census["area_km2"])

sa2_census[[
        "SA2_CODE",
        "SA2_NAME",
        "median_income",
        "children_pct",
        "elderly_pct",
        "population_density"]].head()
# Out:
#     SA2_CODE           SA2_NAME  median_income  children_pct  elderly_pct  \
# 0  206011106     Brunswick East         2087.0      9.632595     8.800440
# 1  206011107     Brunswick West         1786.0     12.746194    12.292220
# 2  206011109  Pascoe Vale South         2245.0     18.209817    14.629451
# 3  206011495  Brunswick - North         2062.0     10.915438    11.567106
# 4  206011496  Brunswick - South         2126.0      9.381499    10.367404
#
#    population_density
# 0         5875.465450
# 1         4504.403817
# 2         3476.162532
# 3         5351.348960
# 4         4749.227012

# %%
# function for min-max standardisation
def standardise(column):
    return (column - column.min()) / (column.max() - column.min())

# reverse standardisation
def reverse_standardise(column):
    return (column.max() - column) / (column.max() - column.min())

# %%
# calculate vulnerability scores
sa2_census["income_score"] = reverse_standardise(sa2_census["median_income"])
sa2_census["elderly_score"] = standardise(sa2_census["elderly_pct"])
sa2_census["children_score"] = standardise(sa2_census["children_pct"])
sa2_census["density_score"] = standardise(sa2_census["population_density"])

# calculate final social vulnerability score
sa2_census["social_vulnerability_score"] = (
    sa2_census["income_score"] +
    sa2_census["elderly_score"] +
    sa2_census["children_score"] +
    sa2_census["density_score"]) / 4

# %%
# make top 10 social vulnerability table
top_social = sa2_census.sort_values(
    by="social_vulnerability_score",
    ascending=False).head(10)

top_social_table = top_social[
    [ "SA2_NAME",
        "median_income",
        "elderly_pct",
        "children_pct",
        "population_density",
        "social_vulnerability_score"]].copy()

top_social_table

top_social_table.to_csv(
    "output/tables/top_10_social_vulnerability_SA2.csv",
    index=False)

# %%
# save census indicators for later merge
sa2_census.drop(columns="geometry").to_csv(
    "data/processed/census_indicators_by_SA2.csv",
    index=False)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

sa2_census.plot(
    column="social_vulnerability_score",
    legend=True,
    legend_kwds={
        "label": "Social vulnerability score",
        "shrink": 0.7},
    edgecolor="grey",
    linewidth=0.1,
    ax=ax)

ax.set_title("Social vulnerability score by SA2 in Greater Melbourne", fontsize=13)
ax.axis("off")

plt.show()

fig.savefig(
    "output/figures/social_vulnerability_map.png",
    dpi=300,
    bbox_inches="tight")

# %% [markdown]
# **Figure X. Social vulnerability score by SA2 in Greater Melbourne.**
# Higher values show SA2s with higher social vulnerability based on weekly median household income, elderly population percentage, children population percentage and population density.
# The social vulnerability score was calculated using four Census-based indicators: median household income, elderly population percentage, children population percentage and population density. Income was treated as a reverse indicator because lower income may reduce the ability of households to adapt to heat stress. The other indicators were treated as positive indicators because higher values may indicate higher sensitivity or exposure. All variables were standardised to a 0–1 scale before being averaged.
